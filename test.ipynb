# %%
from DPInvisibleDecay import DPInvisibleDecay
darkSHINE = DPInvisibleDecay(3e14, 8, verbose=1)
darkSHINE.initialization()
X,Y,Z = darkSHINE.GetGrid()
# Out:
# Welcome to JupyROOT 6.24/06
# 0.001 1e-07 0.26349981129864264
# 0.002 1e-07 0.1427792921926464
# 0.003 1e-07 0.09240027243454553
# 0.004 1e-07 0.06571517862085002
# 0.005 1e-07 0.04960193079335396
# 0.006 1e-07 0.039012876501161683
# 0.007 1e-07 0.03162449512118016
# 0.008 1e-07 0.026232223809001337
# 0.009000000000000001 1e-07 0.02215590889936656
# 0.01 1e-07 0.018985873449970093
# 0.02 1e-07 0.0062015097652826385
# 0.03 1e-07 0.0029243360428669912
# 0.04 1e-07 0.0016577851543631411
# 0.05 1e-07 0.0010497749203161497
# 0.06 1e-07 0.000714873434506679
# 0.07 1e-07 0.0005124565854372066
# 0.08 1e-07 0.00038168953194315445
# 0.09 1e-07 0.00029286320022725045
# 0.1 1e-07 0.0002301091300305087
# 0.2 1e-07 4.1787875629364255e-05
# 0.5 1e-07 2.3149350763853037e-06
# 0.7000000000000001 1e-07 5.082087705416695e-07
# 1.0 1e-07 3.447250712298182e-08
# 0.001 3.162277660168379e-07 1.4563068457308437
# 0.002 3.162277660168379e-07 0.8823413359606354
# 0.003 3.162277660168379e-07 0.61868522556784
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import interp2d

interp_func = interp2d(X, Y, Z, kind='linear')
x_new = np.linspace(-3, 0, 100)
y_new = np.linspace(-7, -2, 100)
z_new = interp_func(x_new, y_new)

plt.rc('text', usetex=True)
plt.contour(X, Y, Z, levels=[0.9])
plt.xlabel('$log_{10}(m_A)$')
plt.ylabel('$log_{10}\epsilon$')
plt.show()
# Out:
# /cvmfs/sft.cern.ch/lcg/views/LCG_101/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/scipy/interpolate/_fitpack_impl.py:977: RuntimeWarning: No more knots can be added because the number of B-spline
# coefficients already exceeds the number of data points m.
# Probable causes: either s or m too small. (fp>s)
# 	kx,ky=1,1 nx,ny=22,16 m=276 fp=0.000006 s=0.000000
#   warnings.warn(RuntimeWarning(_iermess2[ierm][0] + _mess))
